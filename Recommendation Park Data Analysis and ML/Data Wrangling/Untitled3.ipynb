# %%
classfy = {
    'track': ['track glide','fitness track'],
     
    'area': ['synthetic surface','quiet areas and active play areas', 'grassed areas', 'sports field'],
     
    'walking': ['boardwalk', 'rubber pathways'],
     
    'basic facilities': ['car parking', 'public toilet with change table', 'disabled access',
  'some disabled access',
  'play panel and small stage area some disabled access','steps', 'terracotta cats to pat','some shade', 'shade structure', 'lots of shade', 'shade','sheep sculptures','stockyard style fencing','barbecue', 'barbecues', 'barbeque', 'public toilet','picnic table','picnic tables','shop front', 'picnic settings', 'drinking fountain', 'seats'],
     
    'carousel': ['carousels', 'carousel and slide', 'carousel'],
     
    'integrated': ['water play area including a water pump and water channel along the bluestone paving', 'climbing,swinging and balancing elements suspended from timber poles', 'tall tyre swing and tyre spring spinners', 'rocky escarpment with slides,swings and water play', 'combination unit','multi-level play structure','pirate ship play structure','combination units','cubby', 'cubby with slide','fort', 'fort tower', 'small tower', 'wooden tower','platform', 'platforms', 'tower platforms', 'waterplay zone – perfect in summer!', 'rocky escarpment with slides,swings and water play'],
     
    'rocker': ['tall tyre swing and tyre spring spinners', 'spinners', 'spinner','spring rocker', 'rockers', 'rocker', '4-way spring rocker','rocking table','spring rider', 'spring riders'],
     
    'sand': ['sandplay items', 'excavator', 'extensive sandpit with a large digger', 'sandplay toy', 'sandpits', 'sandpit with diggers', 'sandpit', 'sand pit'],
     
    'see-saw': ['see-saw', 'see saw', 'see saws'],
     
    'slide': ['cubby-like structures with climbing and sliding challenges',
  'slide',
  'double slide',
  'spiral slide',
  'carousel and slide',
  'toddler playspace - slide',
  'slides',
  'cubby with slide',
  'slide and climbing features',
  'dragon slide',
  'cubby-like structures with climbing and sliding challenges', 'rocky escarpment with slides,swings and water play'],
     
    'swing': ['climbing,swinging and balancing elements suspended from timber poles', 'tall tyre swing and tyre spring spinners', 'swings',
  'swing',
  '5-way swing',
  'swinging hammocks',
  'liberty swing for wheelchairs',
  '1 x 5 way swing',
  'rocking swing',
  'sandplit and swings',
  'giraffe swing', 'rocky escarpment with slides,swings and water play'],
     
    'climb': ['climbing,swinging and balancing elements suspended from timber poles', 'climbing forest', 
  'cubby-like structures with climbing and sliding challenges',
  'climbers',
  'climbers x 3',
  'climber',
  'rock and rope climbing features',
  'climbing frame',
  'climbing features',
  'rock wall', 'rocky escarpment with slides,swings and water play'],
     
    'bar': ['chin up bar', 'chin up bars', 'monkey bars', 'parallel bars'],
     
    'balance': ['climbing,swinging and balancing elements suspended from timber poles', 'rope bridge', 'balancing bridges','balance beam', 'stepping posts'],
     
    'mini-game': ['tunnels and barrels', 'tunnels', 'play units with mirror panel','tic-tac-toe', 'abacus', 'chalkboard','clock and steering wheel','musical wall','bells','musical elements', 'speaking tubes'],
    'basketball': ['basketball court',
  'play court space with basketball backboard only',
  'temporary basketball court with backboard and ring',
  'basketball rings'],
    'skate$bmx': ['concrete skate ramp', 'skate park','bmx track']}

# %%
class_new = {
    'track': ['track glide','fitness track'],
     
    'carousel': ['carousels', 'carousel and slide', 'carousel'],
     
    'integrated': ['water play area including a water pump and water channel along the bluestone paving', 'climbing,swinging and balancing elements suspended from timber poles', 'tall tyre swing and tyre spring spinners', 'rocky escarpment with slides,swings and water play', 'combination unit','multi-level play structure','pirate ship play structure','combination units','cubby', 'cubby with slide','fort', 'fort tower', 'small tower', 'wooden tower','platform', 'platforms', 'tower platforms', 'waterplay zone – perfect in summer!', 'rocky escarpment with slides,swings and water play'],
     
    'rocker': ['tall tyre swing and tyre spring spinners', 'spinners', 'spinner','spring rocker', 'rockers', 'rocker', '4-way spring rocker','rocking table','spring rider', 'spring riders'],
     
    'sand': ['sandplay items', 'excavator', 'extensive sandpit with a large digger', 'sandplay toy', 'sandpits', 'sandpit with diggers', 'sandpit', 'sand pit'],
     
    'see-saw': ['see-saw', 'see saw', 'see saws'],
     
    'slide': ['cubby-like structures with climbing and sliding challenges',
  'slide',
  'double slide',
  'spiral slide',
  'carousel and slide',
  'toddler playspace - slide',
  'slides',
  'cubby with slide',
  'slide and climbing features',
  'dragon slide',
  'cubby-like structures with climbing and sliding challenges', 'rocky escarpment with slides,swings and water play'],
     
    'swing': ['climbing,swinging and balancing elements suspended from timber poles', 'tall tyre swing and tyre spring spinners', 'swings',
  'swing',
  '5-way swing',
  'swinging hammocks',
  'liberty swing for wheelchairs',
  '1 x 5 way swing',
  'rocking swing',
  'sandplit and swings',
  'giraffe swing', 'rocky escarpment with slides,swings and water play'],
     
    'climb': ['climbing,swinging and balancing elements suspended from timber poles', 'climbing forest', 
  'cubby-like structures with climbing and sliding challenges',
  'climbers',
  'climbers x 3',
  'climber',
  'rock and rope climbing features',
  'climbing frame',
  'climbing features',
  'rock wall', 'rocky escarpment with slides,swings and water play'],
     
    'bar': ['chin up bar', 'chin up bars', 'monkey bars', 'parallel bars'],
     
    'balance': ['climbing,swinging and balancing elements suspended from timber poles', 'rope bridge', 'balancing bridges','balance beam', 'stepping posts'],
     
    'mini-game': ['tunnels and barrels', 'tunnels', 'play units with mirror panel','tic-tac-toe', 'abacus', 'chalkboard','clock and steering wheel','musical wall','bells','musical elements', 'speaking tubes'],
    'basketball': ['basketball court',
  'play court space with basketball backboard only',
  'temporary basketball court with backboard and ring',
  'basketball rings'],
    'skate&bmx': ['concrete skate ramp', 'skate park','bmx track']}

# %%
new = {}
for k,v in class_new.items() :
    for i in v :
        new[i] = k

# %%
new
# Out:
# {'track glide': 'track',
#  'fitness track': 'track',
#  'carousels': 'carousel',
#  'carousel and slide': 'slide',
#  'carousel': 'carousel',
#  'water play area including a water pump and water channel along the bluestone paving': 'integrated',
#  'climbing,swinging and balancing elements suspended from timber poles': 'balance',
#  'tall tyre swing and tyre spring spinners': 'swing',
#  'rocky escarpment with slides,swings and water play': 'climb',
#  'combination unit': 'integrated',
#  'multi-level play structure': 'integrated',
#  'pirate ship play structure': 'integrated',
#  'combination units': 'integrated',
#  'cubby': 'integrated',
#  'cubby with slide': 'slide',
#  'fort': 'integrated',
#  'fort tower': 'integrated',
#  'small tower': 'integrated',
#  'wooden tower': 'integrated',
#  'platform': 'integrated',
#  'platforms': 'integrated',
#  'tower platforms': 'integrated',
#  'waterplay zone – perfect in summer!': 'integrated',
#  'spinners': 'rocker',
#  'spinner': 'rocker',
#  'spring rocker': 'rocker',
#  'rockers': 'rocker',
#  'rocker': 'rocker',
#  '4-way spring rocker': 'rocker',
#  'rocking table': 'rocker',
#  'spring rider': 'rocker',
#  'spring riders': 'rocker',
#  'sandplay items': 'sand',
#  'excavator': 'sand',
#  'extensive sandpit with a large digger': 'sand',
#  'sandplay toy': 'sand',
#  'sandpits': 'sand',
#  'sandpit with diggers': 'sand',
#  'sandpit': 'sand',
#  'sand pit': 'sand',
#  'see-saw': 'see-saw',
#  'see saw': 'see-saw',
#  'see saws': 'see-saw',
#  'cubby-like structures with climbing and sliding challenges': 'climb',
#  'slide': 'slide',
#  'double slide': 'slide',
#  'spiral slide': 'slide',
#  'toddler playspace - slide': 'slide',
#  'slides': 'slide',
#  'slide and climbing features': 'slide',
#  'dragon slide': 'slide',
#  'swings': 'swing',
#  'swing': 'swing',
#  '5-way swing': 'swing',
#  'swinging hammocks': 'swing',
#  'liberty swing for wheelchairs': 'swing',
#  '1 x 5 way swing': 'swing',
#  'rocking swing': 'swing',
#  'sandplit and swings': 'swing',
#  'giraffe swing': 'swing',
#  'climbing forest': 'climb',
#  'climbers': 'climb',
#  'climbers x 3': 'climb',
#  'climber': 'climb',
#  'rock and rope climbing features': 'climb',
#  'climbing frame': 'climb',
#  'climbing features': 'climb',
#  'rock wall': 'climb',
#  'chin up bar': 'bar',
#  'chin up bars': 'bar',
#  'monkey bars': 'bar',
#  'parallel bars': 'bar',
#  'rope bridge': 'balance',
#  'balancing bridges': 'balance',
#  'balance beam': 'balance',
#  'stepping posts': 'balance',
#  'tunnels and barrels': 'mini-game',
#  'tunnels': 'mini-game',
#  'play units with mirror panel': 'mini-game',
#  'tic-tac-toe': 'mini-game',
#  'abacus': 'mini-game',
#  'chalkboard': 'mini-game',
#  'clock and steering wheel': 'mini-game',
#  'musical wall': 'mini-game',
#  'bells': 'mini-game',
#  'musical elements': 'mini-game',
#  'speaking tubes': 'mini-game',
#  'basketball court': 'basketball',
#  'play court space with basketball backboard only': 'basketball',
#  'temporary basketball court with backboard and ring': 'basketball',
#  'basketball rings': 'basketball',
#  'concrete skate ramp': 'skate&bmx',
#  'skate park': 'skate&bmx',
#  'bmx track': 'skate&bmx'}

# %%
import json
with open("Final_Done_vk.json", "w") as outfile:  
    json.dump(class_new, outfile)

# %%
import json
with open("value-key-pair.json", "w") as outfile_1:  
    json.dump(new, outfile_1)

# %%
import json
with open('Final_Done.json') as done:
    done_dict = json.load(done)

# %%
done_new ={}
for k,v in done_dict.items() :
    for i in v :
        done_new[i] = k

# %%
with open("Final_Done_vk.json", "w") as outfile_3:  
    json.dump(done_new, outfile_3)

# %%
import pandas as pd
for k,v in done_dict.items() :
    done_dict[k] = list(set(v))

# %%
for k,v in done_dict.items() :
    temp = pd.Series(v)
    print(temp.value_counts())
# Out:
# stepping posts                       1
# COME UP WITH PROPER BALANCE IMAGE    1
# rope bridge                          1
# balancing bridges                    1
# balance beam                         1
# dtype: int64
# parallel bars    1
# chin up bar      1
# monkey bars      1
# chin up bars     1
# dtype: int64
# play court space with basketball backboard only       1
# basketball rings                                      1
# temporary basketball court with backboard and ring    1
# basketball court                                      1
# dtype: int64
# carousel and slide    1
# carousel              1
# carousels             1
# dtype: int64
# climbing frame                                                1
# climbers                                                      1
# climbing features                                             1
# rock and rope climbing features                               1
# climbers x 3                                                  1
# climber                                                       1
# cubby-like structures with climbing and sliding challenges    1
# rock wall                                                     1
# climbing forest                                               1
# rocky escarpment with slides,swings and water play            1
# dtype: int64
# synthetic surface                                      1
# grassed areas                                          1
# COME UP WITH PROPER GREEN SAFE AREA AND SAFETY TIPS    1
# quiet areas and active play areas                      1
# sports field                                           1
# dtype: int64
# cubby with slide                            1
# combination units                           1
# multi-level play structure                  1
# cubby                                       1
# tall tyre swing and tyre spring spinners    1
# small tower                                 1
# fort                                        1
# combination unit                            1
# wooden tower                                1
# fort tower                                  1
# platform                                    1
# pirate ship play structure                  1
# play units with mirror panel                1
# tower platforms                             1
# platforms                                   1
# dtype: int64
# chalkboard                                                                        1
# clock and steering wheel                                                          1
# musical wall                                                                      1
# musical elements                                                                  1
# tic-tac-toe                                                                       1
# speaking tubes                                                                    1
# bells                                                                             1
# abacus                                                                            1
# COME UP WITH PROPER IMAGE AND LITTLE SAFETY OR ANYTHING INNOVATIVE as for tips    1
# dtype: int64
# 4-way spring rocker                                              1
# rocking table                                                    1
# spring riders                                                    1
# COME UP WITH PROEPR ROCKER image and tips THAT REPRESETNS ALL    1
# spring rocker                                                    1
# spinners                                                         1
# rocker                                                           1
# tall tyre swing and tyre spring spinners                         1
# rockers                                                          1
# spinner                                                          1
# spring rider                                                     1
# dtype: int64
# sandplay toy                             1
# sandpit                                  1
# sandplay items                           1
# extensive sandpit with a large digger    1
# excavator                                1
# sandpit with diggers                     1
# sandpits                                 1
# sand pit                                 1
# dtype: int64
# picnic settings                                         1
# steps                                                   1
# lots of shade                                           1
# picnic table                                            1
# shade structure                                         1
# some shade                                              1
# some disabled access                                    1
# play panel and small stage area some disabled access    1
# picnic tables                                           1
# car parking                                             1
# public toilet                                           1
# public toilet with change table                         1
# shop front                                              1
# sheep sculptures                                        1
# barbecue                                                1
# seats                                                   1
# barbeque                                                1
# disabled access                                         1
# terracotta cats to pat                                  1
# drinking fountain                                       1
# shade                                                   1
# stockyard style fencing                                 1
# barbecues                                               1
# dtype: int64
# see-saw     1
# see saws    1
# see saw     1
# dtype: int64
# skate park                                         1
# COME UP WITH PROPER SKATE IAMGE ANS SAFETY TIPS    1
# concrete skate ramp                                1
# bmx track                                          1
# dtype: int64
# cubby with slide                                              1
# slides                                                        1
# slide and climbing features                                   1
# slide                                                         1
# toddler playspace - slide                                     1
# cubby-like structures with climbing and sliding challenges    1
# spiral slide                                                  1
# dragon slide                                                  1
# carousel and slide                                            1
# double slide                                                  1
# rocky escarpment with slides,swings and water play            1
# dtype: int64
# giraffe swing                                         1
# 1 x 5 way swing                                       1
# sandplit and swings                                   1
# swings                                                1
# swinging hammocks                                     1
# liberty swing for wheelchairs                         1
# tall tyre swing and tyre spring spinners              1
# 5-way swing                                           1
# swing                                                 1
# rocking swing                                         1
# rocky escarpment with slides,swings and water play    1
# dtype: int64
# COME UP WITH POPER TRACK IMAGE AND SAFETY TIPS    1
# track glide                                       1
# fitness track                                     1
# rubber pathways                                   1
# boardwalk                                         1
# dtype: int64
# tunnels and barrels    1
# tunnels                1
# dtype: int64
# water play area including a water pump and water channel along the bluestone paving    1
# waterplay zone – perfect in summer!                                                    1
# rocky escarpment with slides,swings and water play                                     1
# dtype: int64

# %%
for k,v in done_new.items() :
    print('list.append(Equipment(name:'+k+', group: '+v+'))')
# Out:
# list.append(Equipment(name:COME UP WITH PROPER BALANCE IMAGE, group: balance))
# list.append(Equipment(name:rope bridge, group: balance))
# list.append(Equipment(name:balance beam, group: balance))
# list.append(Equipment(name:chin up bar, group: bar))
# list.append(Equipment(name:chin up bars, group: bar))
# list.append(Equipment(name:parallel bars, group: bar))
# list.append(Equipment(name:monkey bars, group: bar))
# list.append(Equipment(name:basketball court, group: basketBall))
# list.append(Equipment(name:play court space with basketball backboard only, group: basketBall))
# list.append(Equipment(name:temporary basketball court with backboard and ring, group: basketBall))
# list.append(Equipment(name:basketball rings, group: basketBall))
# list.append(Equipment(name:carousels, group: carousel))
# list.append(Equipment(name:climbers, group: climb))
# list.append(Equipment(name:rock and rope climbing features, group: climb))
# list.append(Equipment(name:climbing frame, group: climb))
# list.append(Equipment(name:rock wall, group: climb))
# list.append(Equipment(name:COME UP WITH PROPER GREEN SAFE AREA AND SAFETY TIPS, group: greenSafeArea))
# list.append(Equipment(name:grassed areas, group: greenSafeArea))
# list.append(Equipment(name:sports field, group: greenSafeArea))
# list.append(Equipment(name:combination unit, group: integrated))
# list.append(Equipment(name:multi-level play structure, group: integrated))
# list.append(Equipment(name:pirate ship play structure, group: integrated))
# list.append(Equipment(name:combination units, group: integrated))
# list.append(Equipment(name:cubby with slide, group: slide))
# list.append(Equipment(name:fort, group: integrated))
# list.append(Equipment(name:wooden tower, group: integrated))
# list.append(Equipment(name:COME UP WITH PROPER IMAGE AND LITTLE SAFETY OR ANYTHING INNOVATIVE as for tips, group: mini-game))
# list.append(Equipment(name:tic-tac-toe, group: mini-game))
# list.append(Equipment(name:abacus, group: mini-game))
# list.append(Equipment(name:chalkboard, group: mini-game))
# list.append(Equipment(name:musical wall, group: mini-game))
# list.append(Equipment(name:bells, group: mini-game))
# list.append(Equipment(name:speaking tubes, group: mini-game))
# list.append(Equipment(name:spinner, group: Spinners))
# list.append(Equipment(name:spinners, group: Spinners))
# list.append(Equipment(name:COME UP WITH PROEPR ROCKER image and tips THAT REPRESETNS ALL, group: rocker))
# list.append(Equipment(name:spring rocker, group: rocker))
# list.append(Equipment(name:rockers, group: rocker))
# list.append(Equipment(name:rocker, group: rocker))
# list.append(Equipment(name:rocking table, group: rocker))
# list.append(Equipment(name:spring rider, group: rocker))
# list.append(Equipment(name:spring riders, group: rocker))
# list.append(Equipment(name:sandplay toy, group: sand))
# list.append(Equipment(name:sandpits, group: sand))
# list.append(Equipment(name:sandpit with diggers, group: sand))
# list.append(Equipment(name:sandpit, group: sand))
# list.append(Equipment(name:see-saw, group: see-saw))
# list.append(Equipment(name:see saw, group: see-saw))
# list.append(Equipment(name:see saws, group: see-saw))
# list.append(Equipment(name:COME UP WITH PROPER SKATE IAMGE ANS SAFETY TIPS, group: skate))
# list.append(Equipment(name:concrete skate ramp, group: skate))
# list.append(Equipment(name:skate park, group: skate))
# list.append(Equipment(name:bmx track, group: skate))
# list.append(Equipment(name:cubby-like structures with climbing and sliding challenges, group: slide))
# list.append(Equipment(name:slide, group: slide))
# list.append(Equipment(name:double slide, group: slide))
# list.append(Equipment(name:spiral slide, group: slide))
# list.append(Equipment(name:carousel and slide, group: slide))
# list.append(Equipment(name:toddler playspace - slide, group: slide))
# list.append(Equipment(name:slides, group: slide))
# list.append(Equipment(name:slide and climbing features, group: slide))
# list.append(Equipment(name:dragon slide, group: slide))
# list.append(Equipment(name:swings, group: swing))
# list.append(Equipment(name:swing, group: swing))
# list.append(Equipment(name:swinging hammocks, group: swing))
# list.append(Equipment(name:rocking swing, group: swing))
# list.append(Equipment(name:giraffe swing, group: swing))
# list.append(Equipment(name:COME UP WITH POPER TRACK IMAGE AND SAFETY TIPS, group: track))
# list.append(Equipment(name:boardwalk, group: track))
# list.append(Equipment(name:fitness track, group: track))
# list.append(Equipment(name:tunnels and barrels, group: tunnelsAndBarrels))
# list.append(Equipment(name:tunnels, group: tunnelsAndBarrels))
